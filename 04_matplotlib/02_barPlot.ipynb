# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 폰트 설정
mpl.rc('font', family='Malgun Gothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# # 막대 그래프 (Bar graph, Bar chart)
# 범주가 있는 데이터 값을 직사각형의 막대로 표현하는 그래프<br>
# 연속형 변수는 linePlot으로<br>
# https://wikidocs.net/92096

# %%
x = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)
plt.show()

# %% [markdown]
# ## 스타일

# %%
x = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

plt.bar(x, values, width=0.6, align='edge', color="g",
        edgecolor="gray", linewidth=1, tick_label=years, log=True)
plt.show()

# %% [markdown]
# ## 수평막대그래프

# %%
y = np.arange(3)
years = ['2017', '2018', '2019']
values = [100, 400, 900]

plt.barh(y, values, height=-0.6, align='edge', color="g",
        edgecolor="gray", linewidth=3, tick_label=years, log=False)
plt.show()
