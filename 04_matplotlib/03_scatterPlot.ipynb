# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# 폰트 설정
mpl.rc('font', family='Malgun Gothic')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# # 산점도(Scatter Plot)
# 두 변수의 상관 관계를 직교 좌표계의 평면에 데이터를 점으로 표현

# %%
np.random.seed(2020)
N = 50
x = np.random.rand(N)
y = np.random.rand(N)

plt.scatter(x,y)
plt.show()

# %%
np.random.seed(19680801)    # Reproducible random state

N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# ## setosa sepal_length, sepal_width

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
 
iris[iris.species == 'setosa'][['sepal_length','sepal_width']].head()
# Out:
#    sepal_length  sepal_width
# 0           5.1          3.5
# 1           4.9          3.0
# 2           4.7          3.2
# 3           4.6          3.1
# 4           5.0          3.6

# %%
x= iris[iris.species == 'setosa']['sepal_length']
y= iris[iris.species == 'setosa']['sepal_width']

# %%
plt.title('Iris Setosa 품종')
plt.xlabel('sepal_length') ; plt.ylabel('sepal_width') 
plt.scatter(x,y)
plt.show()
