# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('population_age_2020.csv')
df.head()
# Out:
#    지역     총인구수    0~9세  10~19세   20~29세   30~39세   40~49세   50~59세   60~69세  \
# 0  서울  9736962  658355  813563  1455903  1505729  1563968  1539385  1200518
# 1  부산  3410925  241624  281120   434692   431911   518321   580966   511174
# 2  대구  2432883  186623  234528   321487   303397   391997   428622   311274
# 3  인천  2954955  239941  281097   405835   417708   490716   515758   344843
# 4  광주  1456121  125396  162728   207554   191432   244903   234048   155056
#
#    70~79세  80~89세  90~99세  100세 이상
# 0  688818  263939   40404     6380
# 1  285602  109312   14396     1807
# 2  171217   74227    8817      694
# 3  172269   74306   11574      908
# 4   91020   38050    5529      405

# %%
#1 DataFrame의 데이터를 2차원 리스트/어레이에 저장
df.values
# Out:
# array([['서울', 9736962, 658355, 813563, 1455903, 1505729, 1563968,
#         1539385, 1200518, 688818, 263939, 40404, 6380],
#        ['부산', 3410925, 241624, 281120, 434692, 431911, 518321, 580966,
#         511174, 285602, 109312, 14396, 1807],
#        ['대구', 2432883, 186623, 234528, 321487, 303397, 391997, 428622,
#         311274, 171217, 74227, 8817, 694],
#        ['인천', 2954955, 239941, 281097, 405835, 417708, 490716, 515758,
#         344843, 172269, 74306, 11574, 908],
#        ['광주', 1456121, 125396, 162728, 207554, 191432, 244903, 234048,
#         155056, 91020, 38050, 5529, 405],
#        ['대전', 1473125, 120476, 151861, 212143, 199106, 242381, 243526,
#         170291, 88289, 39190, 5523, 339],
#        ['울산', 1145710, 103399, 115623, 147745, 158271, 190698, 211255,
#         136520, 57438, 21610, 2991, 160],
#        ['세종', 343788, 47454, 40574, 36273, 61442, 65714, 42907, 27813,
#         13609, 6863, 1084, 55],
# ...

# %%
#2 1번 결과의 열과 행을 바꾸자 => DataFrame TransPose
df.T.values
# Out:
# array([['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기도', '강원도',
#         '충청북도', '충청남도', '전라북도', '전라남도', '경상북도', '경상남도', '제주도'],
#        [9736962, 3410925, 2432883, 2954955, 1456121, 1473125, 1145710,
#         343788, 13265377, 1539521, 1598599, 2120995, 1815112, 1861894,
#         2658956, 3358828, 670876],
#        [658355, 241624, 186623, 239941, 125396, 120476, 103399, 47454,
#         1178548, 108694, 128290, 179808, 135297, 137868, 198214, 282751,
#         62086],
#        [813563, 281120, 234528, 281097, 162728, 151861, 115623, 40574,
#         1347854, 141975, 153119, 206578, 180675, 172888, 233506, 331566,
#         71539],
#        [1455903, 434692, 321487, 405835, 207554, 212143, 147745, 36273,
#         1769080, 179813, 198910, 243748, 212339, 202760, 291097, 384750,
#         81968],
#        [1505729, 431911, 303397, 417708, 191432, 199106, 158271, 61442,
#         1917785, 169694, 198768, 276553, 195971, 193083, 303472, 418383,
#         84145],
# ...

# %%
#3 DataFrame을 Dictionary로 바꾸는 방법
# https://qastack.kr/programming/26716616/convert-a-pandas-dataframe-to-a-dictionary
df.to_dict('list')
# Out:
# {'지역': ['서울',
#   '부산',
#   '대구',
#   '인천',
#   '광주',
#   '대전',
#   '울산',
#   '세종',
#   '경기도',
#   '강원도',
#   '충청북도',
#   '충청남도',
#   '전라북도',
#   '전라남도',
#   '경상북도',
#   '경상남도',
#   '제주도'],
#  '총인구수': [9736962,
#   3410925,
#   2432883,
#   2954955,
#   1456121,
#   1473125,
#   1145710,
#   343788,
#   13265377,
#   1539521,
#   1598599,
#   2120995,
#   1815112,
#   1861894,
#   2658956,
#   3358828,
#   670876],
#  '0~9세': [658355,
#   241624,
#   186623,
#   239941,
#   125396,
#   120476,
#   103399,
#   47454,
#   1178548,
#   108694,
#   128290,
#   179808,
#   135297,
#   137868,
#   198214,
#   282751,
#   62086],
#  '10~19세': [813563,
#   281120,
#   234528,
#   281097,
#   162728,
#   151861,
#   115623,
#   40574,
#   1347854,
#   141975,
#   153119,
#   206578,
#   180675,
#   172888,
#   233506,
#   331566,
#   71539],
#  '20~29세': [1455903,
#   434692,
#   321487,
#   405835,
#   207554,
#   212143,
#   147745,
#   36273,
#   1769080,
#   179813,
#   198910,
# ...

# %%
df.set_index('지역').to_dict()
# Out:
# {'총인구수': {'서울': 9736962,
#   '부산': 3410925,
#   '대구': 2432883,
#   '인천': 2954955,
#   '광주': 1456121,
#   '대전': 1473125,
#   '울산': 1145710,
#   '세종': 343788,
#   '경기도': 13265377,
#   '강원도': 1539521,
#   '충청북도': 1598599,
#   '충청남도': 2120995,
#   '전라북도': 1815112,
#   '전라남도': 1861894,
#   '경상북도': 2658956,
#   '경상남도': 3358828,
#   '제주도': 670876},
#  '0~9세': {'서울': 658355,
#   '부산': 241624,
#   '대구': 186623,
#   '인천': 239941,
#   '광주': 125396,
#   '대전': 120476,
#   '울산': 103399,
#   '세종': 47454,
#   '경기도': 1178548,
#   '강원도': 108694,
#   '충청북도': 128290,
#   '충청남도': 179808,
#   '전라북도': 135297,
#   '전라남도': 137868,
#   '경상북도': 198214,
#   '경상남도': 282751,
#   '제주도': 62086},
#  '10~19세': {'서울': 813563,
#   '부산': 281120,
#   '대구': 234528,
#   '인천': 281097,
#   '광주': 162728,
#   '대전': 151861,
#   '울산': 115623,
#   '세종': 40574,
#   '경기도': 1347854,
#   '강원도': 141975,
#   '충청북도': 153119,
#   '충청남도': 206578,
#   '전라북도': 180675,
#   '전라남도': 172888,
#   '경상북도': 233506,
#   '경상남도': 331566,
# ...

# %%
# Out:
# {'지역': array([6380, 1807,  694,  908,  405,  339,  160,   55, 4010,  803,  541,
#          885,  817,  822,  960,  739,  266], dtype=int64)}
